# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from collections import Counter

# 读取数据集文件
data = []
with open('anonymous-msweb.test', 'r') as file:
    for line in file:
        data.append(line.strip().split(','))

# %%
# 数据清洗和提取用户浏览记录
df = pd.DataFrame(data, columns=['Type', 'Value1', 'Value2', 'Value3', 'Value4', 'Value5'])
df = df[df['Type'] == 'A']
user_browsing_records = df['Value4'].tolist()

# %%
# 数据探索性分析
most_visited_pages = Counter(user_browsing_records).most_common(5)
page_visit_distribution = pd.Series(user_browsing_records).value_counts()

print("最常被访问的页面：")
print(most_visited_pages)
print("\n页面访问量分布：")
print(page_visit_distribution)
# Out:
# 最常被访问的页面：
# [('"/stream"', 1), ('"/worddev"', 1), ('"/technet"', 1), ('"/sbnmember"', 1), ('"/hardwaresupport"', 1)]
#
# 页面访问量分布：
# "/france"              1
# "/benelux"             1
# "/vbasic"              1
# "/outlook"             1
# "/mstv"                1
# "/news"                1
# "/iesupport"           1
# "/usability"           1
# "/jscript"             1
# "/australia"           1
# "/catalog"             1
# "/ie"                  1
# "/win32devsupport"     1
# "/uk"                  1
# "/msft"                1
# "/spain"               1
# "/transaction"         1
# "/danmark"             1
# "/cze"                 1
# "/netherlands"         1
# "/msexcel"             1
# "/belgium"             1
# "/msmq"                1
# "/italy"               1
# "/vtest"               1
# "/bookshelf"           1
# "/devnews"             1
# "/support"             1
# "/referral"            1
# "/snasupport"          1
#                       ..
# "/referencesupport"    1
# "/msoffice"            1
# "/mspress"             1
# "/turkey"              1
# "/gamesdev"            1
# "/activeplatform"      1
# "/norge"               1
# "/ireland"             1
# "/latam"               1
# "/msdownload."         1
# "/activex"             1
# "/vstudio"             1
# "/ssafe"               1
# "/products"            1
# "/stream"              1
# "/powerpoint"          1
# "/mindshare"           1
# "/mdn"                 1
# "/odbc"                1
# "/netshow"             1
# "/wineguide"           1
# "/worddev"             1
# "/korea"               1
# "/ntserversupport"     1
# "/developr"            1
# "/misc"                1
# "/technet"             1
# "/pictureit"           1
# "/advtech"             1
# "/mail"                1
# Length: 294, dtype: int64

# %%
# 关联规则挖掘
te = TransactionEncoder()
te_ary = te.fit(user_browsing_records).transform(user_browsing_records)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)
frequent_itemsets = apriori(df_encoded, min_support=0.1, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
# 结果评估
rules['antecedent_len'] = rules['antecedents'].apply(lambda x: len(x))
rules = rules[(rules['antecedent_len'] >= 2) &
              (rules['confidence'] > 0.7) &
              (rules['lift'] > 1.2)]

# %%
# 结果分析与应用
optimized_navigation_structure = rules['antecedents'].tolist()

print("\n关联规则：")
print(rules)
print("\n优化导航结构建议：")
print(optimized_navigation_structure)
# Out:
# 关联规则：
#        antecedents         consequents  antecedent support  \
# 242         (", f)                 (o)            0.139456
# 289         (p, ")                 (o)            0.292517
# 309         (p, ")                 (r)            0.292517
# 314         (p, ")                 (s)            0.292517
# 330         (t, ")                 (r)            0.428571
# 335         (", u)                 (r)            0.272109
# 343         (", u)                 (s)            0.272109
# 350         (", u)                 (t)            0.272109
# 430         (f, /)                 (o)            0.139456
# 477         (p, /)                 (o)            0.292517
# 498         (p, /)                 (r)            0.292517
# 503         (p, /)                 (s)            0.292517
# 519         (t, /)                 (r)            0.428571
# 524         (/, u)                 (r)            0.272109
# 532         (/, u)                 (s)            0.272109
# 538         (/, u)                 (t)            0.272109
# 554         (t, a)                 (r)            0.200680
# 562         (t, c)                 (r)            0.142857
# 563         (c, r)                 (t)            0.149660
# 575         (n, r)                 (e)            0.190476
# 578         (t, n)                 (e)            0.183673
# 581         (p, e)                 (o)            0.159864
# 593         (p, e)                 (r)            0.159864
# 596         (p, e)                 (s)            0.159864
# 599         (p, e)                 (t)            0.159864
# 606         (t, e)                 (r)            0.261905
# 609         (e, u)                 (r)            0.159864
# 614         (e, u)                 (s)            0.159864
# 617         (e, u)                 (t)            0.159864
# 619         (o, i)                 (s)            0.183673
# ...            ...                 ...                 ...
# 6848  (o, ", /, u)        (t, p, r, s)            0.180272
# 6849  (o, ", p, u)        (t, /, r, s)            0.146259
# 6850  (o, p, /, u)        (t, ", r, s)            0.146259
# 6851  (p, ", /, u)        (t, o, r, s)            0.166667
# 6854  (t, o, p, s)        (", r, /, u)            0.146259
# 6855  (t, p, ", s)        (o, r, /, u)            0.163265
# 6856  (t, p, /, s)        (o, ", r, u)            0.163265
# 6857  (o, ", p, s)        (t, r, /, u)            0.166667
# 6858  (o, p, /, s)        (t, ", r, u)            0.166667
# 6861  (t, o, ", p)        (/, r, s, u)            0.170068
# 6862  (t, o, p, /)        (", r, s, u)            0.170068
# 6865     (r, s, u)     (t, o, ", /, p)            0.170068
# 6866     (t, r, u)     (s, o, ", /, p)            0.173469
# 6867     (o, r, u)     (s, t, ", /, p)            0.156463
# 6870     (p, r, u)     (s, t, o, ", /)            0.156463
# 6879     (t, s, u)     (r, o, ", /, p)            0.170068
# 6880     (o, s, u)     (r, t, ", /, p)            0.156463
# 6883     (p, s, u)     (r, t, o, ", /)            0.146259
# 6884     (t, o, u)     (r, s, ", /, p)            0.170068
# 6887     (t, p, u)     (r, s, o, ", /)            0.146259
# 6888     (o, ", u)     (r, s, t, /, p)            0.180272
# 6889     (o, /, u)     (r, s, t, ", p)            0.180272
# 6890     (o, p, u)     (r, s, t, ", /)            0.146259
# 6891     (p, ", u)     (r, s, t, o, /)            0.166667
# 6892     (p, /, u)     (r, s, t, o, ")            0.166667
# 6894     (t, p, s)     (r, u, o, ", /)            0.163265
# 6895     (o, p, s)     (r, u, t, ", /)            0.166667
# 6900     (t, o, p)     (r, u, s, ", /)            0.170068
# 6909        (o, u)  (r, s, t, ", /, p)            0.180272
# 6910        (p, u)  (r, s, t, o, ", /)            0.166667
#
#       consequent support   support  confidence      lift  leverage  \
# 242             0.459184  0.108844    0.780488  1.699729  0.044808
# 289             0.459184  0.221088    0.755814  1.645995  0.086769
# 309             0.489796  0.255102    0.872093  1.780523  0.111828
# 314             0.544218  0.210884    0.720930  1.324709  0.051691
# 330             0.489796  0.302721    0.706349  1.442130  0.092809
# 335             0.489796  0.197279    0.725000  1.480208  0.064001
# 343             0.544218  0.207483    0.762500  1.401094  0.059397
# 350             0.428571  0.200680    0.737500  1.720833  0.084062
# 242     2.463719               2
# 289     2.214772               2
# 309     3.988868               2
# 314     1.633220               2
# 330     1.737452               2
# 335     1.855288               2
# 343     1.919083               2
# 350     2.176871               2
# 430     2.463719               2
# 477     2.214772               2
# 498     3.988868               2
# 503     1.633220               2
# 519     1.737452               2
# 524     1.855288               2
# 532     1.919083               2
# 538     2.176871               2
# 554     1.770708               2
# 562     2.142857               2
# 563     2.095238               2
# 575     1.659864               2
# 578     1.493878               2
# 581     2.541837               2
# 593     7.993197               2
# 596     1.530126               2
# 599     2.238095               2
# 606     1.870748               2
# 609     2.179963               2
# 614     1.647828               2
# 617     2.065934               2
# 619     1.538265               2
# ...          ...             ...
# 6848    3.167638               4
# 6849    8.300170               4
# 6850    8.300170               4
# 6851    4.066667               4
# 6854    8.629252               4
# 6855    4.498866               4
# 6856    4.498866               4
# 6857    4.050000               4
# 6858    4.050000               4
# 6861    3.772418               4
# 6862    3.772418               4
# 6865    3.772418               3
# 6866    3.541667               3
# 6867    5.498542               3
# 6870    5.297376               3
# 6879    3.586889               3
# 6880    5.319728               3
# 6883    8.592687               3
# 6884    3.679654               3
# 6887    8.556122               3
# 6888    3.167638               3
# 6889    3.167638               3
# 6890    8.300170               3
# 6891    4.066667               3
# 6892    4.066667               3
# 6894    4.498866               3
# 6895    4.050000               3
# 6900    3.772418               3
# 6909    3.167638               2
# 6910    4.066667               2
#
# [2817 rows x 10 columns]
#
# 优化导航结构建议：
# [frozenset({'"', 'f'}), frozenset({'p', '"'}), frozenset({'p', '"'}), frozenset({'p', '"'}), frozenset({'t', '"'}), frozenset({'"', 'u'}), frozenset({'"', 'u'}), frozenset({'"', 'u'}), frozenset({'f', '/'}), frozenset({'p', '/'}), frozenset({'p', '/'}), frozenset({'p', '/'}), frozenset({'t', '/'}), frozenset({'/', 'u'}), frozenset({'/', 'u'}), frozenset({'/', 'u'}), frozenset({'t', 'a'}), frozenset({'t', 'c'}), frozenset({'c', 'r'}), frozenset({'n', 'r'}), frozenset({'t', 'n'}), frozenset({'p', 'e'}), frozenset({'p', 'e'}), frozenset({'p', 'e'}), frozenset({'p', 'e'}), frozenset({'t', 'e'}), frozenset({'e', 'u'}), frozenset({'e', 'u'}), frozenset({'e', 'u'}), frozenset({'o', 'i'}), frozenset({'t', 'i'}), frozenset({'u', 'i'}), frozenset({'t', 'n'}), frozenset({'n', 'r'}), frozenset({'o', 'p'}), frozenset({'o', 'r'}), frozenset({'p', 'r'}), frozenset({'o', 'p'}), frozenset({'p', 's'}), frozenset({'t', 'p'}), frozenset({'o', 'p'}), frozenset({'o', 'u'}), frozenset({'p', 'u'}), frozenset({'o', 'r'}), frozenset({'o', 's'}), frozenset({'t', 'o'}), frozenset({'o', 'r'}), frozenset({'o', 'u'}), frozenset({'r', 'u'}), frozenset({'t', 'o'}), frozenset({'o', 'u'}), frozenset({'s', 'u'}), frozenset({'t', 'u'}), frozenset({'o', 'u'}), frozenset({'p', 'r'}), frozenset({'p', 's'}), frozenset({'t', 'p'}), frozenset({'p', 'r'}), frozenset({'p', 'u'}), frozenset({'r', 'u'}), frozenset({'t',